# %% [markdown]
# <a href="https://colab.research.google.com/github/saniyaniffa-netizen/Linear-Regression/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opencv-python matplotlib --quiet

# %%
import cv2
from matplotlib import pyplot as pyplot
from google.colab import files

# %%
image_file = "/content/T.jpg"
image = cv2.imread(image_file)

# %%
image = cv2.imread(image_file)
if image is None:
    print(f"Error: Could not load image from {image_file}")
else:
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    pyplot.imshow(image)
    pyplot.show()

# %%
# !wget -O haar_face.xml https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_frontalface_default.xml
face_cascade = cv2.CascadeClassifier('haar_face.xml')
# Out:
# --2026-03-13 05:34:47--  https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_frontalface_default.xml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 930127 (908K) [text/plain]
# Saving to: ‘haar_face.xml’
#
# haar_face.xml       100%[===================>] 908.33K  --.-KB/s    in 0.04s
#
# 2026-03-13 05:34:47 (24.8 MB/s) - ‘haar_face.xml’ saved [930127/930127]

# %%
gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)

# %%
faces = face_cascade.detectMultiScale(gray, scaleFactor =1.1, minNeighbors = 5)

# %%
for(x,y,w,h) in faces:
  cv2.rectangle(image_rgb, (x,y), (x+w, y+h), (255,0,0), 2)

# %%
pyplot.figure(figsize=(8,6))
pyplot.imshow(image_rgb)
pyplot.title(f'Faces detected: {len(faces)}')
pyplot.axis('off')
pyplot.show()

# %%
# !pip install opencv-python matplotlib --quiet

# %%
import cv2
from matplotlib import pyplot as pyplot
from google.colab import files

# %%
image_file = "/content/R.jpg"
image = cv2.imread(image_file)

# %%
import cv2
from matplotlib import pyplot as pyplot

image_file = "/content/R.jpg"
image = cv2.imread(image_file)
if image is None:
    print(f"Error: Could not load image from {image_file}")
else:
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    pyplot.imshow(image_rgb)
    pyplot.show()
# Out:
# Error: Could not load image from /content/R.jpg

# %%
sample_chat{
    "hello":"hi there! how can i help you today?",
    "hi":"hello! how are you?",
    "how are you?":"I'm just a bot, but I'm doing great! how about you?",
    "what is computer vision":"computer vision is a field of AI that allows computer to see a",
    "what is AI":"stand's for artificial intelligence, which enables machines to perform task",
    "what is deep learning":"deep learning is a subset of artificial intelligence that uses neural network to learn",
    "bye":"goodbye! how a nice day!",
    "thank you":"you're welcome! happy to help."
}

# %%
def sample_chat(user_input,chat_history=[]):
    user_input_lower = user_input.lower()
    response=None

    for key in sample_data:
      if key in user_input_lower:
        response=sample_data[key]
        break

    if not response:
      response="sorry, i don't understand that. can you ask something else?"

    chat_history.append(("you",user_input))
    chat_history.append(("bot",response))
    return response, chat_history

# %%
print("welcome to mini conversation AI")
print("type 'exit' or 'quit' to end the chat.\n")
chat_history=[]

while True:
  user_input=input("you:")
  if user_input.lower()in ['exit',"quit"]:
    print("chat ended.goodbye!")
    break

    bot_response,chat_history=samnple_chat(user_input,chat_history)
    print("bot:",bot_response)
# Out:
# welcome to mini conversation AI
# type 'exit' or 'quit' to end the chat.
#
# you:hi
# you:hlo
