# %% [markdown]
# <a href="https://colab.research.google.com/github/saniyaniffa-netizen/Linear-Regression/blob/main/git_hub_com.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import AgglomerativeClustering

df = pd.read_csv("/content/Mall_Customers.csv")

x = df[["Annual_Income_(k$)","Spending_Score"]]

agg_model = AgglomerativeClustering(n_clusters = 3)

df['cluster'] = agg_model.fit_predict(x)

plt.scatter(x['Annual_Income_(k$)'],x['Spending_Score'], c=df['cluster'], cmap = 'rainbow')
plt.xlabel("Animal Income")
plt.ylabel("Spending Score")
plt.title("Agglomerative Clustering")
plt.show()

df.to_csv("agglo_clustered_data.csv",index=False)
print("Agglomerative clusterd dataset saved as 'agglo_clustered_data.csv'")
# Out:
# Agglomerative clusterd dataset saved as 'agglo_clustered_data.csv'
